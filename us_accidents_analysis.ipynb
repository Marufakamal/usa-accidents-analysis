# %% [markdown]
# <a href="https://colab.research.google.com/github/Marufakamal/usa-accidents-analysis/blob/main/us_accidents_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('us-accidents-analysis')
jovian.set_colab_id('1UCDSQzaJo8GkBhSyXo_udyXRl2MsEA1P')
# Out:
#      |████████████████████████████████| 71kB 3.7MB/s
# ...

# %% [markdown]
# Us accidents exploratory data analysis

# %% [markdown]
# Todo- talk about the EDA
#
# Todo- talk about the dataset(source, what it contains, how it will be useful)
# -kaggle
# -information about accidents
# -can be used for useful data to prevent accidents
#
# 1.   mention that this does not contain data about New York

# %% [markdown]
# Downloading the data from kaggle using Jovian

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
download_url ='https://www.kaggle.com/sobhanmoosavi/us-accidents'
od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: marufakamal
# Your Kaggle Key: ··········
#   3%|▎         | 9.00M/290M [00:00<00:03, 78.0MB/s]
# ...
# 100%|██████████| 290M/290M [00:02<00:00, 116MB/s]

# %%
data_filename = './us-accidents/US_Accidents_Dec20_Updated.csv'

# %% [markdown]
# Data prepration and cleaning
#
# -Load the file using Pandas
# -Look at some imformation about data and information
# -Fix any missing or incorrect values

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                 ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0              A-1         2  ...               Day                   Day
# 1              A-2         2  ...               Day                   Day
# 2              A-3         2  ...             Night                 Night
# 3              A-4         2  ...               Day                   Day
# 4              A-5         3  ...               Day                   Day
# ...            ...       ...  ...               ...                   ...
# 2906605  A-2906606         2  ...               Day                   Day
# 2906606  A-2906607         2  ...             Night                 Night
# 2906607  A-2906608         2  ...               Day                   Day
# 2906608  A-2906609         2  ...             Night                 Night
# 2906609  A-2906610         2  ...               Day                   Day
#
# [2906610 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
  df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  2.906610e+06  2.906610e+06  ...     2.599447e+06       1.605284e+06
# mean   2.288649e+00  3.653027e+01  ...     7.818111e+00       1.119459e-02
# std    5.541618e-01  5.013964e+00  ...     5.431171e+00       1.540812e-01
# min    1.000000e+00  2.455527e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.366453e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.609977e+01  ...     7.000000e+00       0.000000e+00
# 75%    3.000000e+00  4.037505e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900220e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# working with the missing and incorrect values

# %% [markdown]
# percentage of missing values per column

# %%
missing_percentages = df.isnull().sum().sort_values(ascending=False) / len(df)
missing_percentages
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# Amenity                  0.000000
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# ...

# %%
missing_percentages[missing_percentages !=0].plot(kind='barh')

# %% [markdown]
# Remove columns that we don't want to use

# %% [markdown]
# Exploratory analysis and visualization
# columns to analyse
#
#
# 1.   start_Time
# 2.   Weather_condition
# 3.   state
# 4.  Temperature
# 5.  city
# 6.  start Lat, start Lng
# 7.  Roundabout

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.City
# Out:
# 0                Greenville
# 1                 Charlotte
# 2                 Los Gatos
# 3               Carson City
# 4           Fort Lauderdale
#                  ...
# 2906605             Houston
# 2906606              Colton
# 2906607               Miami
# 2906608      Salt Lake City
# 2906609    Colorado Springs
# Name: City, Length: 2906610, dtype: object

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Los Angeles        68411
# Houston            68265
# Charlotte          56176
# Miami              49965
# Dallas             48525
#                    ...
# Dowling                1
# Richland VIII          1
# Manastash Ridge        1
# Rochdale               1
# Childress              1
# Name: City, Length: 11789, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# Los Angeles      68411
# Houston          68265
# Charlotte        56176
# Miami            49965
# Dallas           48525
# Austin           38808
# Raleigh          31355
# Atlanta          29244
# Sacramento       28984
# Orlando          28092
# Nashville        25277
# Baton Rouge      25080
# Minneapolis      22469
# San Diego        22329
# Phoenix          21370
# Oklahoma City    21292
# Portland         19432
# Richmond         18343
# Seattle          17384
# Saint Paul       17266
# Name: City, dtype: int64

# %%
cities_by_accident[:20].plot(kind='barh')

# %%
import seaborn as sns 
sns.set_style("darkgrid")

# %%
sns.histplot(cities_by_accident, log_scale=True)

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# Dameron            1
# Brierfield         1
# Mount Arlington    1
# Shubuta            1
# Villas             1
#                   ..
# Dowling            1
# Richland VIII      1
# Manastash Ridge    1
# Rochdale           1
# Childress          1
# Name: City, Length: 1306, dtype: int64

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# is the distribution of acciednts by hour the same on weekdays as on weekends?

# %% [markdown]
# For Sunday( the 6 represents Sunday here)

# %%
sundays_start_time =  df.Start_Time[df.Start_Time.dt.dayofweek == 6 ]
sns.distplot(sundays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# For Monday ( the o represents Monday here)

# %%
mondays_start_time =  df.Start_Time[df.Start_Time.dt.dayofweek == 0 ]
sns.distplot(mondays_start_time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Roundabouts for accidents

# %%
df.Roundabout
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2906605    False
# 2906606    False
# 2906607    False
# 2906608    False
# 2906609    False
# Name: Roundabout, Length: 2906610, dtype: bool

# %%
roundabouts_by_accident = df.Roundabout.value_counts()
roundabouts_by_accident
# Out:
# False    2906468
# True         142
# Name: Roundabout, dtype: int64

# %% [markdown]
# the months prone to accidents

# %%
sns.distplot(df.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# start latitude and longitude

# %%
df.Start_Lat
# Out:
# 0          34.808868
# 1          35.090080
# 2          37.145730
# 3          39.110390
# 4          26.102942
#              ...
# 2906605    29.813824
# 2906606    34.068890
# 2906607    25.702200
# 2906608    40.660140
# 2906609    38.831749
# Name: Start_Lat, Length: 2906610, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -82.269157
# 1          -80.745560
# 2         -121.985052
# 3         -119.773781
# 4          -80.265091
#               ...
# 2906605    -95.399437
# 2906606   -117.342010
# 2906607    -80.335556
# 2906608   -111.952460
# 2906609   -104.748161
# Name: Start_Lng, Length: 2906610, dtype: float64

# %%
import folium

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (34.808868, -82.26915699999998)

# %%
map = folium.Map()
marker = folium.Marker((lat, lon))
marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.01 * len(df)))
lat_lon_pairs = zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# Summary and conclusion
#
#
# *   no data from New York
# *   less than 5% of the cities have more than 1000 yearly accidents
# * over 1300 cities just had one accidents
# * the num of accidents per cities decreses exponentially
# * high percentage of accidents occur between 6 am to 10 am in the morning. 3 pm to 6 pm is another major time  when the accidents occurs
# * Roundabouts are not that accident prone

# %% [markdown]
# Ask and answer questions
#
#
# 1.   are there more accidents in hotter or colder areas?
# 2.   which states have the highest number of accidents?
# 3.  does New york show up inthe data / if yes why is the count lower if it the most populated city?
# 4. among the top 100 cities in number 0f accidents, which states do they belong to most frequebntly?
# 5. what time of the day and which days of the week the accidents mostly occurs ?
# 6. when is the accidents per unit traffic is highest?
